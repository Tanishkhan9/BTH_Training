# %%
#Classification supervised learning:Predict the class . in which the input belongs to
#regression supervised learning :predict a real number based on inpt features


#Unsupervised Learning(Uses)
#Clustering: Natural Grouping in data by measuring similarity or distance
#K-Means: Divides data in "k" Distinct Clusters
# 1.to find the number of clusters 'k'
# 2.Send each point to nearest cluster centre
# 3.Updates the centre until it stops changing

# Used Cases : Customer Segmentation , Document Clustering , Market Based Analysis . Image Compression
# Dimensonality Reduction (PCA) :Principal Component Analysis-- Reduce the number of input variable while retaining essential information
#PCA :1- Convert features into principal components
#     2-Captures maximum variance in dinmensions
#     3-Noise Reduction , Visualize high dimension datat,Preprocessing before clustering and classification
#

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt


#load data

iris=load_iris()
x=iris.data


#Apply KMEans
kmeans=KMeans(n_clusters=3,random_state=422)
kmeans.fit(x)
labels=kmeans.labels_

#Visualise (first 2 features)

plt.scatter(x[:,0],x[:,1],c=labels,cmap="viridis")
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('K-Means Clustering')
plt.show()

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score , precision_score,recall_score


#load data

y=iris.target



#split into training and testing_sets

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=52)



#train a random forest classifier

model=RandomForestClassifier(random_state=42)
model.fit(X_train,y_train)



#Make prediction on the training set

y_pred=model.predict(X_test)


#EVALUATE the model
accuracy=accuracy_score(y_test,y_pred)
precision =precision_score(y_test,y_pred,average='macro')
recall=recall_score(y_test,y_pred,average='macro')


#DIsplay the results

print("Accuracy:" ,accuracy)
print("Precision:", precision)
print("Recall:",recall)
# Out:
# Accuracy: 0.95
# Precision: 0.9545454545454546
# Recall: 0.9565217391304347

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans


#Sample data --Replace with your own data manually


data={
    'Annual Income':[99,98,97,96,95,94,93,92,91,90],
    'Spending Score':[89,88,87,86,85,84,83,82,81,80]
}
df=pd.DataFrame(data)


#Apply K-means with 3 Clusters

kmeans=KMeans(n_clusters=3,random_state=42)
df['Cluster']=kmeans.fit_predict(df)




#Visualize the cluster or data

plt.scatter(df['Annual Income'],df['Spending Score'],c=df['Cluster'],cmap='rainbow')
plt.xlabel("Annual Income")
plt.ylabel("Spending socore")
plt.title("customer Cluster")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.datasets import make_classification


#Simulate a dataset with 100 features

X,y=make_classification(n_samples=200,n_features=100,random_state=0)



#Apply PcA to reduce with 2 dimension

pca =PCA(n_components=2)
X_reduced=pca.fit_transform(X)


#plot in 2d


plt.scatter(X_reduced[:,0],X_reduced[:,1],c=y,cmap='viridis',s=40)
plt.xlabel('Principal component 1')
plt.ylabel('principal component 2')
plt.title('khansahab')
plt.grid(True)
plt.show()
